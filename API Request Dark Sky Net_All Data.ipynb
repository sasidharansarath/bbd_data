# %%
# https://api.darksky.net/forecast/[key]/[latitude],[longitude],[time]

import json, urllib
import datetime # https://docs.python.org/2/library/datetime.html
import requests # http://docs.python-requests.org/en/master/user/quickstart/
import pandas as pd
from pandas import Series, DataFrame
from geopy.geocoders import Nominatim # https://pypi.org/project/geopy/

api_key = "e2bdab8f57436bcf7b634998ab5e3fa2" # https://darksky.net/dev/account


Berlin = [52.5143,13.3227] # https://www.gps-coordinates.net/
 
dt = datetime.datetime(2018,10,17,11,0,0)

timestamp = (dt - datetime.datetime(1970,1,1,0,0,0)).total_seconds() # https://www.tutorialspoint.com/How-to-convert-Python-date-to-Unix-timestamp

par = {'units':'si'}

url = "https://api.darksky.net/forecast/"+str(api_key)+"/"+str(Berlin[0])+","+str(Berlin[1])+","+str(int(timestamp))

weather = requests.get(url, params = par)

w_data = weather.json()

w_df = pd.DataFrame(w_data['hourly']['data'])

reqd_data = w_df[['time','cloudCover']]

print 'Latitude: ',Berlin[0],"",'Longitude: ',Berlin[1]
print
print 'DateTime: ', dt
print
print 'UNIXtime: ', int(timestamp)
print
print weather.url
print
print w_df
# Out:
# Latitude:  52.5143  Longitude:  13.3227
#
# DateTime:  2018-10-17 11:00:00
#
# UNIXtime:  1539774000
#
# https://api.darksky.net/forecast/e2bdab8f57436bcf7b634998ab5e3fa2/52.5143,13.3227,1539774000?units=si
#
#     apparentTemperature  cloudCover  dewPoint  humidity         icon   ozone  \
# 0                  9.02        0.02      6.99      0.87  clear-night  282.07
# 1                  8.61        0.05      7.59      0.93  clear-night  282.31
# 2                  8.02        0.03      6.41      0.90  clear-night  281.59
# 3                  6.92        0.03      6.59      0.93  clear-night  281.27
# 4                  7.01        0.04      6.00      0.93  clear-night  280.95
# 5                  7.01        0.00      6.59      0.97  clear-night  280.59
# 6                  7.01        0.00      6.00      0.93  clear-night  280.40
# 7                  6.61        0.00      6.00      0.96  clear-night  280.18
# 8                  7.21        0.00      6.59      0.96    clear-day  280.19
# 9                  9.20        0.00      6.59      0.84    clear-day  280.52
# 10                12.61        0.00      8.59      0.77    clear-day  280.98
# 11                14.79        0.00      8.41      0.66    clear-day  281.32
# 12                17.20        0.00      8.41      0.56    clear-day  281.57
# 13                19.20        0.00      8.41      0.50    clear-day  281.81
# 14                20.21        0.00      8.81      0.48    clear-day  281.96
# 15                20.61        0.00      8.81      0.47    clear-day  284.87
# 16                20.61        0.00      8.81      0.47    clear-day  284.64
# 17                19.61        0.00      9.40      0.52    clear-day  284.33
# 18                18.02        0.00      8.81      0.55    clear-day  284.13
# 19                15.20        0.00      9.99      0.71  clear-night  283.94
# 20                13.02        0.00      9.00      0.77  clear-night  283.67
# 21                12.61        0.00      9.59      0.82  clear-night  283.16
# 22                11.20        0.00      9.59      0.90  clear-night  282.84
# 23                10.01        0.00      8.01      0.87  clear-night  282.67
#
#     precipIntensity  precipProbability  pressure summary  temperature  \
# 0                 0                  0   1019.10   Clear         9.02
# 1                 0                  0   1019.10   Clear         8.61
# 2                 0                  0   1019.38   Clear         8.02
# 3                 0                  0   1019.31   Clear         7.61
# 4                 0                  0   1019.27   Clear         7.01
# 5                 0                  0   1019.23   Clear         7.01
# 6                 0                  0   1019.35   Clear         7.01
# 7                 0                  0   1019.47   Clear         6.61
# 8                 0                  0   1019.71   Clear         7.21
# 9                 0                  0   1019.83   Clear         9.20
# 10                0                  0   1019.83   Clear        12.61
# 11                0                  0   1019.72   Clear        14.79
# 12                0                  0   1019.59   Clear        17.20
# 13                0                  0   1019.27   Clear        19.20
# 14                0                  0   1019.08   Clear        20.21
# 15                0                  0   1018.62   Clear        20.61
# 16                0                  0   1018.33   Clear        20.61
# 17                0                  0   1018.20   Clear        19.61
# 18                0                  0   1018.39   Clear        18.02
# 19                0                  0   1018.70   Clear        15.20
# 20                0                  0   1019.01   Clear        13.02
# 21                0                  0   1019.17   Clear        12.61
# 22                0                  0   1019.24   Clear        11.20
# 23                0                  0   1019.24   Clear        10.01
#
#           time  uvIndex  visibility  windBearing  windGust  windSpeed
# 0   1539727200        0       10.01        262.0      1.13       1.00
# 1   1539730800        0       16.09        302.0      1.15       0.47
# 2   1539734400        0       10.01        300.0      1.05       0.50
# 3   1539738000        0       10.01        235.0      1.50       1.50
# 4   1539741600        0       10.01        211.0      1.21       1.17
# 5   1539745200        0        9.59        234.0      1.05       1.00
# 6   1539748800        0        8.77        320.0      1.04       0.41
# 7   1539752400        0        7.56        339.0      1.03       0.50
# 8   1539756000        0        8.37          NaN      1.10       0.00
# 9   1539759600        0        8.77        233.0      1.73       1.31
# 10  1539763200        1       10.01        235.0      1.86       1.28
# 11  1539766800        1       10.01          0.0      1.97       1.50
# 12  1539770400        2       10.01        143.0      2.60       2.60
# 13  1539774000        2       10.01        273.0      2.21       1.37
# 14  1539777600        2       10.01        276.0      2.23       2.07
# 15  1539781200        1       10.01        342.0      2.10       1.82
# 16  1539784800        1       10.01        139.0      2.10       2.09
# 17  1539788400        0       10.01        136.0      2.10       2.06
# 18  1539792000        0       10.01        185.0      1.71       1.50
# 19  1539795600        0       10.01        283.0      1.44       0.61
# 20  1539799200        0       10.01        257.0      1.27       0.85
# 21  1539802800        0       10.01        196.0      1.35       1.30
# 22  1539806400        0       10.01        308.0      1.28       0.60
# 23  1539810000        0       10.01         96.0      2.10       2.10
