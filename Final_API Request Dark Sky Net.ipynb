# %%
# https://api.darksky.net/forecast/[key]/[latitude],[longitude],[time]

import json, urllib
import datetime # https://docs.python.org/2/library/datetime.html
import requests # http://docs.python-requests.org/en/master/user/quickstart/
import pandas as pd
from pandas import Series, DataFrame
# from geopy.geocoders import Nominatim # https://pypi.org/project/geopy/

api_key = "e2bdab8f57436bcf7b634998ab5e3fa2" # https://darksky.net/dev/account


Berlin = [52.5143,13.3227] # https://www.gps-coordinates.net/
 
dt = datetime.datetime(2018,9,6,12,0,0)

timestamp = (dt - datetime.datetime(1970,1,1,0,0,0)).total_seconds() # https://www.tutorialspoint.com/How-to-convert-Python-date-to-Unix-timestamp

par = {'units':'si'}

url = "https://api.darksky.net/forecast/"+str(api_key)+"/"+str(Berlin[0])+","+str(Berlin[1])+","+str(int(timestamp))

weather = requests.get(url, params = par)

w_data = weather.json()

w_df = pd.DataFrame(w_data['hourly']['data'])

reqd_data = w_df[['time','apparentTemperature','cloudCover','summary']]

reqd_data['time_std'] = reqd_data['time'].apply(lambda x: datetime.datetime.utcfromtimestamp(int(x)))

reqd_data1 = reqd_data[['time','time_std','apparentTemperature','cloudCover','summary']]

print 'Latitude: ',Berlin[0],"",'Longitude: ',Berlin[1]
print
print 'DateTime: ', dt
print
print 'UNIXtime: ', int(timestamp)
print
print weather.url
print
print w_df.columns
print
print reqd_data1

if True:
    reqd_data1.to_csv(r"C:\Users\Sarath Sasidharan\Desktop\Required Weather Data.csv", index = None)
# Out:
# Latitude:  52.5143  Longitude:  13.3227
#
# DateTime:  2018-09-06 12:00:00
#
# UNIXtime:  1536235200
#
# https://api.darksky.net/forecast/e2bdab8f57436bcf7b634998ab5e3fa2/52.5143,13.3227,1536235200?units=si
#
# Index([u'apparentTemperature', u'cloudCover', u'cloudCoverError', u'dewPoint',
#        u'humidity', u'icon', u'precipType', u'pressure', u'pressureError',
#        u'summary', u'temperature', u'time', u'uvIndex', u'visibility',
#        u'windBearing', u'windSpeed'],
#       dtype='object')
#
#           time            time_std  apparentTemperature  cloudCover  \
# 0   1536184800 2018-09-05 22:00:00                17.61        0.48
# 1   1536188400 2018-09-05 23:00:00                16.61        0.48
# 2   1536192000 2018-09-06 00:00:00                16.02        0.48
# 3   1536195600 2018-09-06 01:00:00                15.61        0.48
# 4   1536199200 2018-09-06 02:00:00                15.20        0.50
# 5   1536202800 2018-09-06 03:00:00                15.61        0.51
# 6   1536206400 2018-09-06 04:00:00                15.20        0.53
# 7   1536210000 2018-09-06 05:00:00                15.61        0.55
# 8   1536213600 2018-09-06 06:00:00                16.61        0.56
# 9   1536217200 2018-09-06 07:00:00                17.61        0.19
# 10  1536220800 2018-09-06 08:00:00                19.02        0.59
# 11  1536224400 2018-09-06 09:00:00                21.02        0.59
# 12  1536228000 2018-09-06 10:00:00                22.43        0.19
# 13  1536231600 2018-09-06 11:00:00                24.01        0.19
# 14  1536235200 2018-09-06 12:00:00                23.42        0.34
# 15  1536238800 2018-09-06 13:00:00                24.01        0.44
# 16  1536242400 2018-09-06 14:00:00                25.01        0.61
# 17  1536246000 2018-09-06 15:00:00                24.01        0.60
# 18  1536249600 2018-09-06 16:00:00                24.01        0.59
# 19  1536253200 2018-09-06 17:00:00                22.61        0.58
# 20  1536256800 2018-09-06 18:00:00                21.62        0.56
# 21  1536260400 2018-09-06 19:00:00                20.61        0.54
# 22  1536264000 2018-09-06 20:00:00                19.61        0.51
# 23  1536267600 2018-09-06 21:00:00                18.61        0.50
#
#           summary
# 0   Partly Cloudy
# 1   Partly Cloudy
# 2   Partly Cloudy
# 3   Partly Cloudy
# 4   Partly Cloudy
# 5   Partly Cloudy
# 6   Partly Cloudy
# 7   Partly Cloudy
# 8   Partly Cloudy
# 9           Clear
# 10  Partly Cloudy
# 11  Partly Cloudy
# 12          Clear
# 13          Clear
# 14  Partly Cloudy
# 15  Partly Cloudy
# 16  Mostly Cloudy
# 17  Mostly Cloudy
# 18  Partly Cloudy
# 19  Partly Cloudy
# 20  Partly Cloudy
# 21  Partly Cloudy
# 22  Partly Cloudy
# 23  Partly Cloudy
# c:\python27\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
